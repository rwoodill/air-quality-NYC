# %%
import pandas
from pymongo import MongoClient
from pandas.io.json import json_normalize
import geopandas as gpd

# %%
df_raw = gpd.read_file("NewYorkCityTruckRoutes_20231205.geojson")
df_raw.head()
# Out:
#   truckroute coun_dist thrutunl objectid_1 thrubrg ltdlocal streetcode  \
# 0          Y      14.0     None        1.0    None     None     242820
# 1          Y       8.0     None        2.0    None     None     226130
# 2          Y      15.0     None        3.0    None     None     226910
# 3          Y      12.0     None        4.0    None     None     253870
# 4          Y      12.0     None        5.0    None     None     277150
#
#   localbrg borocd restrictio  ... boroname thruexwy routetype localtunl  \
# 0     None  205.0       None  ...    Bronx     None     Local      None
# 1     None  201.0       None  ...    Bronx     None     Local      None
# 2     None  206.0       None  ...    Bronx     None     Local      None
# 3     None  212.0       None  ...    Bronx        Y   Through      None
# 4     None  212.0       None  ...    Bronx     None     Local      None
#
#   borocode               street segmentid  \
# 0      2.0        JEROME AVENUE   0073071
# 1      2.0      EAST 149 STREET   0077201
# 2      2.0      EAST 175 STREET   0078397
# 3      2.0  NEW ENGLAND THRUWAY   0119835
# 4      2.0    WHITE PLAINS ROAD   0132595
#
#                                      nyc_reg cong_dist  \
# 0  NYCDOT Traffic Rules, Section 4-13-(f)(2)      15.0
# 1  NYCDOT Traffic Rules, Section 4-13-(f)(2)      15.0
# 2  NYCDOT Traffic Rules, Section 4-13-(f)(2)      15.0
# 3  NYCDOT Traffic Rules, Section 4-13-(f)(1)      16.0
# 4  NYCDOT Traffic Rules, Section 4-13-(f)(2)      16.0
#
#                                             geometry
# 0  MULTILINESTRING ((-73.90733 40.85382, -73.9055...
# 1  MULTILINESTRING ((-73.90342 40.81151, -73.9032...
# 2  MULTILINESTRING ((-73.90052 40.84512, -73.8993...
# 3  MULTILINESTRING ((-73.83434 40.87203, -73.8344...
# 4  MULTILINESTRING ((-73.86497 40.88067, -73.8649...
#
# [5 rows x 23 columns]

# %%
df_raw.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 32939 entries, 0 to 32938
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   truckroute  32939 non-null  object
#  1   coun_dist   32939 non-null  object
#  2   thrutunl    230 non-null    object
#  3   objectid_1  32939 non-null  object
#  4   thrubrg     561 non-null    object
#  5   ltdlocal    223 non-null    object
#  6   streetcode  32939 non-null  object
#  7   localbrg    340 non-null    object
#  8   borocd      32939 non-null  object
#  9   restrictio  987 non-null    object
#  10  shape_leng  32939 non-null  object
#  11  st_sen_dis  32939 non-null  object
#  12  assem_dist  32939 non-null  object
#  13  boroname    32939 non-null  object
#  14  thruexwy    4970 non-null   object
#  15  routetype   32939 non-null  object
#  16  localtunl   0 non-null      object
#  17  borocode    32939 non-null  object
#  18  street      32939 non-null  object
#  19  segmentid   32939 non-null  object
#  20  nyc_reg     32939 non-null  object
#  21  cong_dist   32939 non-null  object
#  22  geometry    32939 non-null  geometry
# dtypes: geometry(1), object(22)
# memory usage: 5.8+ MB

# %%
df_slim = df_raw[['geometry', 'street', 'boroname', 'routetype']]
df_slim.head()
# Out:
#                                             geometry               street  \
# 0  MULTILINESTRING ((-73.90733 40.85382, -73.9055...        JEROME AVENUE
# 1  MULTILINESTRING ((-73.90342 40.81151, -73.9032...      EAST 149 STREET
# 2  MULTILINESTRING ((-73.90052 40.84512, -73.8993...      EAST 175 STREET
# 3  MULTILINESTRING ((-73.83434 40.87203, -73.8344...  NEW ENGLAND THRUWAY
# 4  MULTILINESTRING ((-73.86497 40.88067, -73.8649...    WHITE PLAINS ROAD
#
#   boroname routetype
# 0    Bronx     Local
# 1    Bronx     Local
# 2    Bronx     Local
# 3    Bronx   Through
# 4    Bronx     Local

# %%
df_slim.to_csv("shorter_nyc_truck_routes", index=False)
